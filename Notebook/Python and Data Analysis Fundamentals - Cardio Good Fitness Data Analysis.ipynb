# %% [markdown]
# # Python & Data Analysis Fundamentals - Good Cardio Fitness Data Analysis

# %% [markdown]
# ##  Student - Charles Kilpatrick
# ##  Submission Date - January 7, 2023

# %% [markdown]
# ## Summary of Customer Profile for Overall Dataset
#
# There is a total of 180 users in the dataset comprised of 104 males and 76 females.
#
# Product- There are 80 TM195 users, 60 TM498 users and 40 TM798 users in the dataset.
#
# Age- The mean age of 28.8 years is greater than the median age of 26.0 years. The minimum value is 18.0 years and the maximum value is 50.0 years. The modal value is 25.0. The age data was divided ino three bins with 30.0% of the users in the 18-24 years bin, 32.78 % of the users in the 25-29 years bin and 37.22 % of the users in the 30-50 years bin. The age data is right skewed and there are three outlier values greater than the boxplot right whisker value of 46.5.
#
# Gender- The users are 104 male (57.78%) male and 76 female (42.22%) users.
#
# Education- The mean education value is 15.6 years, the median value is 16.0 years, the minimum value is 12.0 years, the maximum value is 21.0 years. The modal value is 16.0 years. There are three outliers with values greater than the right whisker value of 19 years.
#
# Marital Status- There are 107 partnered (59.44%) and 73 single (42.22%) users.
#
# Usage- The mean usage of 3.5 is greater than the median usage of 3.0. The minimum usage is 2.0 and the maximum usage is 7.0. The modal value is 3.0. There are two data points greater than the boxplot right whisker value of 5.5.  The data is right skewed.
#
# Fitness- The mean fitness value of 3.3 is greater than the median value of 3.0. The minimum fitness is 1.0 and the maximum value is 5.0.  The modal value is 3.0.  There is one data point less than the boxplot left whisker value of 1.5. The data is right skewed.
#
# Miles- Some of the data for the miles category was unreasonably high for a user to attain on a weekly basis, however, the guidance provided in the Project Discussion Forum was that none of the miles data should be discarded. The mean value of 103.2 is greater than the median value of 94.0. The minimum value is 21.0 and the maximum value is 360.0. The modal value is 85.0.  There are eight data points greater than the boxplot right whisker value of 187.9.  The data is right skewed.
#
# Income - The mean income of 53720 per year is greater than the median value of 50597 per year. The minimum income is 29562 per year and the maximum income is 104581 per year. The modal value is 45480 per year. Income was divided into three bins. The low income bin (income 29000 - 45000) comprised 27.2% of the dataset, the middle income bin (income 45000 - 56000) comprised 43.3% of the dataset, and the high income bin (income greater than 56000) comprised 29.4% of the dataset. There are eleven data points to the right of the boxlot right whisker value of 80582. The data is right skewed.

# %% [markdown]
# ### Summary Of TM195 Customer Profile
#
# There is a total of 80 TM195 users in the dataset comprised of 40 males and 40 females.
#
# Age- The mean age is 28.6 years and the median age is 26.0 years, thus the data is right skewed. The minimum value is 18.0 and the maximum value is 50.0.  The user ages were assigned to three bins and 33.8% of the TM195 users are in the 18-24 years bin, 32.5% of the users are in the 25-29 years bin, and 33.8% of the users are in the 30-50 years bin. The is one boxplot outlier greater than the right whisker value of 48.0 years.
#
# Gender- The users were identified as 50.0 % male and 50.0 % female.
#
# Education- The mean value of 15.0 years is less than the median value of 16 years due to 37.5% of the users having 14 years of education. The minimum value is 12.0 years and the maximum value is 18.0 years. The modal value is 16.0 years and there are boxplot no outliers.
#
# Marital Status- The users are 60.0% partnered and 40.0% single.
#
# Usage- The mean is 3.09 and the median is 3.0. The minimum value is 2.0 and the maximum value is 5.0.  The modal value is 3.0. There are no boxplot outliers.
#
# Fitness- The mean value of 2.96 is very close to the median value of 3.0.  The minimum value is 1.0 and the maximum value is 5.0.  The modal value is 3.0. Because the 25% and 75% quartile values are both 3.0,  any values below 3.0 show up as low outliers and any values above 3.0 show up as boxplot high outliers.
#
# Miles- The mean value is 82.8 miles and the median value is 85.0 miles. The minimum value is 38.0 miles and the maximum value is 188.0 miles. The modal value is 85.0 miles. The are three oulier values grater than the boxplot right whisker value of 140.5.
#
# Income - The mean income is 46418 per year and the median income is 46617 per year. The minimum value is 29562 per year and the maximum value is 68220 per year. The low income bin (income 29000 - 45000) comprised 42.5% of the users, the middle income bin (income 45000 - 56000) comprised 45.0% of the users and the high income bin (income greater than 56000) comprised 12.5% of the users.

# %% [markdown]
# ### Summary Of TM498 Customer Profile
#
# There is a total of 60 TM498 users comprised of 31 males and 29 females in the dataset.
#
# Age-The mean age is 28.9 years and the median age is 26.0 years, thus the data is right skewed. The minimum value is 19.0 and the maximum value is 48.0.  The user ages were assigned to three bins and 28.3% of the users are in the 18-24 years bin, 26.7% of the users are in the 25-29 years bin, and 45.0% of the users are in the 30-50 years bin. The modal value is 25.0. The is one outlier greater than the boxplot right whisker value of 47.1 years.
#
# Gender- The users were identified as 51.7 % male and 48.3 % female.
#
# Education-The mean value of 15.1 years is less than the median value of 16 years  The minimum value is 12.0 years and the maximum value is 18.0 years. The modal value is 16.0 years and there are no outliers.
#
# Marital Status- The partnered users comprise 60% of the TM498 users and 40% of the users are single.
#
# Usage- The mean usage of 3.1 is close to the median value of 3.0 The minimum value is 2.0 and the maximum value is 5.0. The modal value is 3.0. There are outliers both to the left of the boxplot low value whisker and the the right of the boxplot high value whisker. This is because the 25 percentile value 3.0 is very close to the 75 percentile value of 3.25 and thius the IQR is very small.
#
# Fitness- The mean value of 2.9 is very close to the median value of 3.0.  The minimum value is 1.0 and the maximum value is 3.0.  The modal value is 3.0. Because the 25% and 75% quartile values are both 3.0, the IQR is zero any values below 3.0 show up as boxplot low outliers and any values above 3.0 show up as boxplot high outliers.
#
# Income- The mean income of 48974 per year is less than the median value of 49460 per year. The minimum income is 31836 per year and the maximum income is 67083 per year. The modal value is 45480 per year. The low income bin (income 29000 - 45000) comprised 25.0% of the dataset, the middle income bin (income 45000 - 56000) comprised 55.0% of the dataset, and the high income bin (income greater than 56000) comprised 20.0% of the dataset. There is one data points to the right of the boxlot right whisker value of 66230. There is one data point to the left of the boxplot low whisker which has a value of 32121.
#
# Miles- The mean value is 87.9 miles and the median value is 85.0 miles. The minimum value is 21.0 miles and the maximum value is 212.0 miles. The modal value is 95.0 miles. There are very few users with a miles value of greater than 130 miles. There are two outlier values greater than the boxplot right whisker value of 169.0.

# %% [markdown]
# ### Summary of TM798 Customer Profile
#
# There is a total of 40 TM798 users comprised of 33 males and 7 females in the dataset.
#
# Age- The mean age of 29.1 years is greater than the median age is 27.0 years and thus data is right skewed. The minimum age is 22 years and the maximum age is 48 years. The age data was assigned to one of three bins.  The 18 - 24 years age group is 25.0% of the users. The 25 -29 age group is 42.5% of the users and the 30 - 50 years age group is 32.5% of the users. Five of the 40 values are outliers greater than the right whisker (38.5 years). The age modal value is 25.
#
# Gender- The users were identified as 82.5% male and 17.5% female.
#
# Education- The mean education of 17.325 years is less than the median education of 18.0 years,  thus the data is left skewed. The minimum education is 14.0 years and the maximum education is 21.0 years. The education modal value is 18.0 years. There are no outliers in the data.
#
# Marital Status- The users are 57.5% partnered and 42.5% single
#
# Usage- The mean usage of 4.8 is close to the median value of 5.0 The minimum value is 3.0 and the maximum value is 7.0. The modal value is 4.0. There is one outlier greater than the boxplot right whisker (6.5).
#
# Fitness- The mean fitness of 4.625 is less than the median value of 5.0 and the data is left skewed. The minimum fitness is 3.0 and the maximum fitness is 5.0.  The modal value is 5.0 and there are no outliers.
#
# Miles- The mean miles value is 166.9 and is greater than the median value of 160.0.  The data is right skewed. There are no users with miles less than 80 and the maximum miles is 360. There is one outlier which is greater than the right whisker value of 320. The modal values are 180 miles and 200 miles which both had a frequency of 6 values of the 40 data points for this product.
#
# Income - The mean income of 75442 is less than the median income of 76569 per year. The users income was divided into three bins with 0.0% of the users in the low income bin (income 29000 - 45000), 22.5% of the users are in the middle income bin (income 45000 - 56000) and 77.5% of the users are in the high income bin (income greater than 56000). There are no users with income less han 48556 and the maximum income is 104581. There are no outliers.

# %% [markdown]
# ### Summary Of Differences Between Customer Profiles For The Different Products
#
# The TM195 product appears to be a lower cost, entry level product with 42.5% of the users in the low income bin, 45% in the middle income bin,  and only 12.5% of the users in the high income bin. The income for TM195 users is less than the overall averages for the dataset. The users are 50% female and 50% male. The female gender group was determined to have lower incomes than males in this study which may factor into the why the female proportion in this user group is greater than the overall dataset proportion of 42.2% female.
#
# The TM195 median fitness is 3.0, the median usage is 3.0, and the median miles is 85.0. The user ages are 33.8% in the 18-24 age bin, 32.5% in the 25-29 age bin, and 33.8% in the 30-50 age bin. Among the three products, the TM195 users group has the greatest proportion of users in the 18-24 age bin. TM195 users self assess a 3.0 fitness level, 3.0 median usage and median miles are 85.0.  The fitness level, median usage amd miles for the TM195 group are identical to the TM498 user group and lower than the corresponding values for the TM798 group. The TM195 users group contains more females, is younger, and less affluent than users of the other two products.  The proportion of partnered users is 60%, which is close to the value for the overall dataset and to the proportions of partnered status for the TM498 and TM798 users.
#
#
# The TM498 appears to be a middle level quality product with 25% of users in the low income bin, 55% of users in the middle income bin, and 20% of users in the high income bin. The TM498 users have the greatest proportion of users in the 30-50 age bin of any of the three products. The age data for the TM498 users is 28.3% in the 18-24 age bin, 26.7% in the 25-29 category, and 45.0% in the 30-50 age bin. The TM498 users are 48.3% female which is slightly greater than the 42.2 % females in the overall dataset. The median fitness is 3.0, median miles is 85.0, and median usage is 3.0.  This is identical to the corresponding values for the TM195 users.  The marital status is 60% partnered which is very close to the value for the overall dataset and for the users of the other two products.
#
#
# Based on the TM798 user income, user miles, user fitness and usage, it is apparent that the TM798 product is the highest cost, high end product whose user base exercises very diligently and self assesses the highest median fitness level among the three user groups. The TM798 users have the lowest proportion of female users with only 17.5% of users identifying as female. The TM798 users have the highest income of any of the three user groups. There are no users in the low income bin, 22.5% of users are in the middle income bin and 77.5% of users are in the high income bin. The median fitness is 5.0, the median usage is 5.0 and the median miles is 160. All three of these values are much greater than those for TM195 or TM498 users. The proportion of partnered users is 57.5% which is very close to that of users of the other two products and the overall dataset.

# %% [markdown]
# ### Summary Of Insights and Recommendations For Targeting New Customers
#
#
# It is observed that the proportion of women using the TM798 product appears to be unusually low. According to to the womensrunning.com website 45.7% of American marathon participants are women. It would be expected that a greater proportion of women would be using high quality cardiovascular training equipment.
#
# Additionally it was seen that there are none of the TM798 users are less than 22 years old.
#
# These are recommendations to increase the number of new customers and to channel them toward the most expensive product:
#
# 1. Investigate the differences between the TM798 and TM498 and determine if there are any reasons other than cost why the TM498 product has a much greater proportion of female users. Incorporate features into the TM798 which make it more user friendly for females.
#
# 2. There are no TM798 users below 22 years old.  The age of 22 is generally associated with the age of graduating from university and gaining employment, with a subsequent income increase. Establish a program where students about to graduate from a university can purchase a TM798 product with a time delay before payments start, as some car dealerships have done.
#
# 3. Investigate whether some TM195 and TM498 users are upgrading to competitor's products. Incorporate design changes to the TM498 and TM798 as necessary to retain customers who plan to upgrade.
#
# 4. Investigate standardizing the hardware for the TM195, TM498, and TM798 and offer a variety of cloud app subscription plans for the fitness and performance monitoring. This would allow young, often lower income users to use the cardiovascular fitness products and gradually upgrade as their fitness training needs and budget allow.
#
# 5. There are no users above 50 years of age. Incorporate features to make the equipment more user friendly for older users.

# %%
# Import Libraries For Reading and Manipulating Data
import numpy as np
import pandas as pd
import statistics


# Import Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Defining the function for creating boxplot and hisogram - Function provided by Mentor In GL Session
def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize)  # creating the 2 subplots
    
    sns.boxplot(data=data, x=feature, ax=ax_box2, showmeans=True, color="mediumturquoise")  # boxplot will be created and a star will indicate the mean value of the column
    
    if bins:
      sns.histplot(data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, color="mediumpurple")
    else: 
      sns.histplot(data=data, x=feature, kde=kde, ax=ax_hist2, color="mediumpurple")  # For histogram
    
    ax_hist2.axvline(data[feature].mean(), color="green", linestyle="--")  # Add mean to the histogram
    
    ax_hist2.axvline(data[feature].median(), color="black", linestyle="-")  # Add median to the histogram

# %%
# Import the project dataset
df=pd.read_csv("CardioGoodFitness.csv")

# %%
## Explore dataset and allocate age and income data into bins
#View dataset first five rows
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
#View dataset last five rows
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
# Overview of the dataset shape 
print("Dataset rows =", df.shape[0], "and columns =", df.shape[1])
# Out:
# Dataset rows = 180 and columns = 9

# %%
# View the data types of the dataset columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# Determine whether there is any missing data
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# Check for duplicated entries
df.duplicated().sum()
# Out:
# 0

# %%
#Print value counts for the age variable
print(df["Age"].value_counts().sort_index(ascending = True))
# Out:
# 18     1
# 19     4
# 20     5
# 21     7
# 22     7
# 23    18
# 24    12
# 25    25
# 26    12
# 27     7
# 28     9
# 29     6
# 30     7
# 31     6
# 32     4
# 33     8
# 34     6
# 35     8
# 36     1
# 37     2
# 38     7
# 39     1
# 40     5
# 41     1
# 42     1
# 43     1
# 44     1
# 45     2
# 46     1
# 47     2
# 48     2
# 50     1
# Name: Age, dtype: int64

# %%
#Print nomalized value counts for the age variable
print(df["Age"].value_counts(normalize=True).sort_index(ascending = True))
# Out:
# 18    0.005556
# 19    0.022222
# 20    0.027778
# 21    0.038889
# 22    0.038889
# 23    0.100000
# 24    0.066667
# 25    0.138889
# 26    0.066667
# 27    0.038889
# 28    0.050000
# 29    0.033333
# 30    0.038889
# 31    0.033333
# 32    0.022222
# 33    0.044444
# 34    0.033333
# 35    0.044444
# 36    0.005556
# 37    0.011111
# 38    0.038889
# 39    0.005556
# 40    0.027778
# 41    0.005556
# 42    0.005556
# 43    0.005556
# 44    0.005556
# 45    0.011111
# 46    0.005556
# 47    0.011111
# 48    0.011111
# 50    0.005556
# Name: Age, dtype: float64

# %%
#  Allocate age data into three bins

df["Age_Bin"] = pd.cut(df.Age, bins = [18, 24,29,50], include_lowest=True, labels = ["Age_18_24", "Age_25_29", "Age_30_50"])

# %%
# Allocate income data into three bins

df["Income_Bin"] = pd.cut(df.Income, bins = [29000, 45000,56000,105000], include_lowest=True, labels = ["Income_Low", "Income_Mid", "Income_Hi"])

# %%
# View dataframe first five rows
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   TM195   18    Male         14        Single      3        4   29562
# 1   TM195   19    Male         15        Single      2        3   31836
# 2   TM195   19  Female         14     Partnered      4        3   30699
# 3   TM195   19    Male         12        Single      3        3   32973
# 4   TM195   20    Male         13     Partnered      4        2   35247
#
#    Miles    Age_Bin  Income_Bin
# 0    112  Age_18_24  Income_Low
# 1     75  Age_18_24  Income_Low
# 2     66  Age_18_24  Income_Low
# 3     85  Age_18_24  Income_Low
# 4     47  Age_18_24  Income_Low

# %%
# View dataframe last five rows
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles    Age_Bin Income_Bin
# 175    200  Age_30_50  Income_Hi
# 176    200  Age_30_50  Income_Hi
# 177    160  Age_30_50  Income_Hi
# 178    120  Age_30_50  Income_Hi
# 179    180  Age_30_50  Income_Hi

# %%
# High level statistical summary of dataframe numerical value columns
df.describe(include="all").T
# Out:
#                count unique         top freq          mean           std  \
# Product          180      3       TM195   80           NaN           NaN
# Age            180.0    NaN         NaN  NaN     28.788889      6.943498
# Gender           180      2        Male  104           NaN           NaN
# Education      180.0    NaN         NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2   Partnered  107           NaN           NaN
# Usage          180.0    NaN         NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN         NaN  NaN      3.311111      0.958869
# Income         180.0    NaN         NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN         NaN  NaN    103.194444     51.863605
# Age_Bin          180      3   Age_30_50   67           NaN           NaN
# Income_Bin       180      3  Income_Mid   78           NaN           NaN
#
#                    min       25%      50%      75%       max
# ...

# %% [markdown]
# ### A complete summary for all of these statistical values entitled "Summary of Customer Profile for Overall Dataset" is presented at the top of this study.

# %%
# Print value counts for he overall dataset age bins
print(df["Age_Bin"].value_counts().sort_index(ascending = True))
# Out:
# Age_18_24    54
# Age_25_29    59
# Age_30_50    67
# Name: Age_Bin, dtype: int64

# %%
# Print normalized value counts for he overall dataset age bins
print(df["Age_Bin"].value_counts(normalize=True).sort_index(ascending = True))
# Out:
# Age_18_24    0.300000
# Age_25_29    0.327778
# Age_30_50    0.372222
# Name: Age_Bin, dtype: float64

# %% [markdown]
# ### Observations
#
# The age data is assigned to three bins all with > 30% of the data points: 30.00 % of the users are in the age 18 to 24 bin, 32.78 % of the users are in the age 25 to 29 bin, and 37.22 % of the users are in the age 30 to 50 bin.

# %%
# Print value counts for he overall dataset age bins
print(df["Income_Bin"].value_counts().sort_index(ascending = True))
# Out:
# Income_Low    49
# Income_Mid    78
# Income_Hi     53
# Name: Income_Bin, dtype: int64

# %%
# Print normalized value counts for he overall dataset age bins
print(df["Income_Bin"].value_counts(normalize=True).sort_index(ascending = True))
# Out:
# Income_Low    0.272222
# Income_Mid    0.433333
# Income_Hi     0.294444
# Name: Income_Bin, dtype: float64

# %% [markdown]
# ### Observations
#
# The income data is assigned to three bins:  27.22 % of the users are in the low income bin,
# 43.33 % of the users are in the middle income bin, and 29.44 % of the users are in the high income bin.

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Univariate Analysis

# %%
# Present vertical boxplots of the overall dataset age bin data
plt.figure(figsize=(15,7))
sns.boxplot(x=df["Age_Bin"], y=df["Age"])
# Out:
# <Axes: xlabel='Age_Bin', ylabel='Age'>

# %% [markdown]
# ### Observations
#
# - The age data is right skewed as will be shown in a boxplot and histogram presented later. Customer ages range between 18 and
#   50.

# %%
# Present vertical boxplots of the overall dataset income bin data
plt.figure(figsize=(15,7))
sns.boxplot(x=df["Income_Bin"], y=df["Income"])
# Out:
# <Axes: xlabel='Income_Bin', ylabel='Income'>

# %% [markdown]
# ### Observations
#
#
# - The income data is right skewed as will be shown in a boxplot and histogram presented later. Customer incomes range between
#   29562 and 104581.

# %%
#Present histogram and boxplot for overall dataset age data
histogram_boxplot(df,'Age')

# %% [markdown]
# ### Observations
# - The age data is right skewed with a mean age of 28.8 years which is greater tha the median age of 26 years.
# - Over 27% of the customers are between the ages of 23 to 26.
# - Customer ages range between 18 and 50. There are three outliers which are greater than the right whisker, however these data
#   points appear to be valid and will be retained.

# %%
#Calculate age modal value
df['Age'].mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %%
#Present histogram and boxplot for overall dataset education data
histogram_boxplot(df,'Education')

# %% [markdown]
# ### Observations
# - The mean education value is 15.6 years, the median value is 16.0 years, the minimum value is 12.0 years, the maximum value is
#   21.0 years.
# - There are three outliers with values greater than the right whisker value of 19 years.

# %% [markdown]
# Histogram and boxplot for Usage variable

# %%
#Calculate education modal value
df['Education'].mode()
# Out:
# 0    16
# Name: Education, dtype: int64

# %%
#Present histogram and boxplot for overall dataset usage data
histogram_boxplot(df,'Usage')

# %% [markdown]
# ### Observations
#
# - The mean usage of 3.5 is greater than the median usage of 3.0. The minimum usage is 2.0 and the maximum usage is 7.0.
# - The modal value is 3.0. There are two data points greater than the boxplot right whisker value of 5.5.  The data is right
#   skewed.

# %%
#Calculate usage data modal value
df['Usage'].mode()
# Out:
# 0    3
# Name: Usage, dtype: int64

# %%
#Present histogram and boxplot for overall dataset fitness data
histogram_boxplot(df,'Fitness')

# %% [markdown]
# ### Observations
#
# - The mean fitness value of 3.3 is greater than the median value of 3.0.
# - The minimum fitness is 1.0 and the maximum value is 5.0.
# - The modal value is 3.0.  There is one data point less than the boxplot left whisker value of 1.5.

# %%
df['Fitness'].mode()
# Out:
# 0    3
# Name: Fitness, dtype: int64

# %%
#Present histogram and boxplot for overall dataset income data
histogram_boxplot(df,'Income')

# %% [markdown]
# ### Observations
#
# - The mean income of 53720 per year is greater than the median value of 50597 per year.
# - The minimum income is 29562 per year and the maximum income is 104581 per year.
# - Income was divided into three bins. There are eleven data points to the right of the boxlot right whisker value of 80582. The
#   data is right skewed.

# %%
#Compute income data modal value
df['Income'].mode()
# Out:
# 0    45480
# Name: Income, dtype: int64

# %%
#Present histogram and boxplot for overall dataset miles data
histogram_boxplot(df,'Miles')

# %% [markdown]
# ### Observations
#
# - Some of the data for the miles category was unreasonably high for a user to attain on a weekly basis, however, the guidance
#   provided in the Project Discussion Forum was that none of the miles data should be discarded.
# - The mean value of 103.2 is greater than the median value of 94.0.
# - The minimum value is 21.0 and the maximum value is 360.0. There are eight data points greater than the boxplot right whisker
#   value of 187.9.
# - The data is right skewed.

# %%
df['Miles'].mode()
# Out:
# 0    85
# Name: Miles, dtype: int64

# %% [markdown]
# Boxplots Of All Numerical Variables Together For Outlier Detection and Handling

# %%
#Present vertical boxplots of all numerical variables together for visualizing relative numbers of outliers
# outlier detection using boxplot
# selecting the numerical columns of data and adding their names in a list 
numeric_columns = ['Age','Education','Usage','Fitness','Income', 'Miles']
plt.figure(figsize=(15, 12))

for i, variable in enumerate(numeric_columns):
    plt.subplot(3, 3, i + 1)
    plt.boxplot(df[variable], whis=1.5)
    plt.tight_layout()
    plt.title(variable)

# %% [markdown]
# ### Observations
#
# - The miles and income variables have a much greater number of outliers.

# %% [markdown]
# ### High Level Summary Of Overall Dataset Categorical Values

# %%
# Determine the counts of unique categorical levels in each column
# Make list of columns containing categorical data
cols_cat = ['Gender', 'MaritalStatus', 'Product', 'Age_Bin', 'Income_Bin']

# Print unique categorical level counts for each column
for column in cols_cat:
  print(df[column].value_counts())
  print('-' * 20)
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64
# --------------------
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64
# --------------------
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64
# --------------------
# Age_30_50    67
# Age_25_29    59
# Age_18_24    54
# Name: Age_Bin, dtype: int64
# --------------------
# Income_Mid    78
# Income_Hi     53
# Income_Low    49
# Name: Income_Bin, dtype: int64
# --------------------

# %%
#Calculate normalized fraction of unique categorical levels in each column
for column in cols_cat:
  print(df[column].value_counts(normalize=True))
  print('-' * 20)
# Out:
# Male      0.577778
# Female    0.422222
# Name: Gender, dtype: float64
# --------------------
# Partnered    0.594444
# Single       0.405556
# Name: MaritalStatus, dtype: float64
# --------------------
# TM195    0.444444
# TM498    0.333333
# TM798    0.222222
# Name: Product, dtype: float64
# --------------------
# Age_30_50    0.372222
# Age_25_29    0.327778
# Age_18_24    0.300000
# Name: Age_Bin, dtype: float64
# --------------------
# Income_Mid    0.433333
# Income_Hi     0.294444
# Income_Low    0.272222
# Name: Income_Bin, dtype: float64
# --------------------

# %%
#Present a countplot of the overall dataset gender data
sns.countplot(data=df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Observations
#
#
# - The dataset includes 104 males (57.78 %) and 76 females(42.22 %).

# %%
#Present a countplot of the overall dataset marital status data
sns.countplot(data=df, x="MaritalStatus")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The data set includes 107 customers (59.44 %) who are partnered and 73 customers (40.56 %) who are single.

# %%
#Present a countplot of the overall dataset product data
sns.countplot(data=df, x="Product")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - There are 80 model TM195 treadmills (44.44 %) being used. There are 60 model TM498 (33.33 %) being used and 40 model TM798
#   treadmills (22.22 %) being used.

# %%
#Present a countplot of the overall dataset age bin data
sns.countplot(data=df, x="Age_Bin")
# Out:
# <Axes: xlabel='Age_Bin', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The age data was divided ino three bins with 30.0% of the users in the 18-24 years bin, 32.78 % of the users in the 25-29
#   years bin and 37.22 % of the users in the 30-50 years bin.

# %%
#Present vertical boxplots of the overall dataset age bin data
plt.figure(figsize=(15,7))
sns.boxplot(x=df["Age_Bin"], y=df["Age"])
# Out:
# <Axes: xlabel='Age_Bin', ylabel='Age'>

# %%
#Present a countplot of the overall dataset income bin data
sns.countplot(data=df, x="Income_Bin")
# Out:
# <Axes: xlabel='Income_Bin', ylabel='count'>

# %% [markdown]
#  ### Observations
#
# - The low income bin (income 29000 - 45000) comprised 27.2% of the dataset, the middle income bin (income 45000 - 56000)
#   comprised 43.3% of the dataset, and the high income bin (income greater than 56000) comprised 29.4% of the dataset.

# %%
#Present vertical boxplots of the overall dataset income bin data
plt.figure(figsize=(15,7))
sns.boxplot(x=df["Income_Bin"], y=df["Income"])
# Out:
# <Axes: xlabel='Income_Bin', ylabel='Income'>

# %% [markdown]
# ### Observations
#
# - All of the overall dataset categorical variables are discussed in the markdown entitled "Summary of Customer Profile for
#   Overall Dataset" at the top of this study.

# %% [markdown]
# ###  Multivariate Analysis

# %%
#Create a 6 x 6 correlation matrix and check for correlation among numerical values
num_var = ['Age','Education','Usage','Fitness','Income', 'Miles']

corr = df[num_var].corr()

# plot the heatmap

plt.figure(figsize=(15, 7))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="YlGnBu", cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Observations
#
# - Income is positively correlated with age, education, usage, fitness, and miles.
# - Miles is positively correlated with usage, fitness, and income.
# - Fitness is positively correlated with usage, income, and miles.
# - Usage is positively correlated with fitness, income, and miles.
# - Education is positively correlated with income. Age is positively correlated with income.

# %%
#Present pairplot of overall dataset numerical values
sns.pairplot(data=df[numeric_columns], kind="scatter", corner=True)

# %% [markdown]
# ### Observations
#
# - Although the heatmap indicated almost zero correlation between age and miles, from inspection a linear regressin analysis of
#   these two variables would be expected to have a positive slope.

# %%
#Present jointplot of overall dataset fitness and miles
plt.figure(figsize=(15,7))
sns.jointplot(data=df, x = "Miles", y = "Fitness", kind = "reg")

# %% [markdown]
# ### Observations
#
# - The jointplot confirms the positive correlation

# %%
#Present jointplot of overall dataset usage and fitness
plt.figure(figsize=(15,7))
sns.jointplot(data=df, x = "Usage", y = "Fitness", kind = "reg")

# %% [markdown]
# ### Observations
#
# - The jointplot confirms the positive correlation.

# %%
# Present lineplot of income and age with gender as a hue
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x = "Age", y = "Income", hue = "Gender", errorbar=('ci', False))
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %% [markdown]
# ### Observations
#
# - Line plot shows males tend to have greater income at most ages.
# - Both the fitness 25% and 75% percentile for females is 3.0, whereas the fitness 25% percentile for males is 3.0 and the 75%
#   percentile is 4.0.
# - Fitness is positively correlated with usage for both males and females.

# %%
#Present lineplot for age and usage with hue gender
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x = "Age", y = "Usage", hue = "Gender", errorbar=('ci', False))
# Out:
# <Axes: xlabel='Age', ylabel='Usage'>

# %% [markdown]
# ### Observations
#
# - Males tend to have higher usage than females.

# %%
#Present violinplot of income and gender
sns.violinplot(data=df, x="Gender", y="Income", orient = "v")
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %% [markdown]
# ### Observations
#
# - Males have a greater proportion of higher income users.

# %%
#Present lineplot of age and income with product as hue
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x = "Age", y = "Income", hue = "Product", errorbar=('ci', False))
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %% [markdown]
# ### Observations
#
# - TM195 and TM498 users have approximately equal income.  TM798 users have a significantly higher income across all ages.

# %%
#Present lineplot of age and miles with product as hue
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x = "Age", y = "Miles", hue = "Product", errorbar=('ci', False))
# Out:
# <Axes: xlabel='Age', ylabel='Miles'>

# %% [markdown]
# ### Observations
#
# - TM195 and TM498 users have approximately equal miles.  TM798 users have significantly higher miles across all ages.

# %%
#Present lineplot of miles and income with product as hue
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x = "Miles", y = "Income", hue = "Product", ci=False)
# Out:
# <AxesSubplot:xlabel='Miles', ylabel='Income'>

# %% [markdown]
# ### Observations
#
# - The proportion of TM795 users increases as miles and income increase. There are some TM498 users who have a relatively high
#   income and miles less than 50.

# %%
#Present countplot of products with gender as hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Product", hue = "Gender")
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Women are significantly underrepresented among TM798 users.

# %%
#Present countplot of products with marial status as hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Product", hue = "MaritalStatus")
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Marital status is not significant for product selection.

# %%
#Countplot of product with age bin as hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Product", hue = "Age_Bin")
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Most important market for the TM498 are 30-50 age bin. Most important markket for TM798 is the 25-29 age bin.

# %%
#Countplot for products with income bin as a hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Product", hue = "Income_Bin")
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Low income users favor TM195.  Middel income users favor TM195 or TM498. High income users favor TM798.

# %%
#Countplot of gender with age bin as a hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Gender", hue = "Age_Bin")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Observations
#
# Males have greater numbers than females in all age bins.

# %%
#Countplot of gender with income bin as a hue
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Gender", hue = "Income_Bin")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Numbers of males and females are roughly equal in the low income bin, however men outnumber women in the middle and high
#   income bins.

# %%
#Extract a data frame consisting only of female cusomers for furher analysis of this category
df_Female = df[df["Gender"] == "Female"]

# %%
#View top 5 roes for female dataframe date
df_Female.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 11   TM195   22  Female         14     Partnered      3        2   35247
#
#     Miles    Age_Bin  Income_Bin
# 2      66  Age_18_24  Income_Low
# 5      66  Age_18_24  Income_Low
# 6      75  Age_18_24  Income_Low
# 9      85  Age_18_24  Income_Low
# 11     66  Age_18_24  Income_Low

# %%
#View bottom five rows for female dataframe data
df_Female.tail()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 152   TM798   25  Female         18     Partnered      5        5   61006
# 157   TM798   26  Female         21        Single      4        3   69721
# 162   TM798   28  Female         18     Partnered      6        5   92131
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 171   TM798   33  Female         18     Partnered      4        5   95866
#
#      Miles    Age_Bin Income_Bin
# 152    200  Age_25_29  Income_Hi
# 157    100  Age_25_29  Income_Hi
# 162    180  Age_25_29  Income_Hi
# 167    280  Age_30_50  Income_Hi
# 171    200  Age_30_50  Income_Hi

# %%
#Descriptive summary of statistics for female users
df_Female.describe(include="all").T
# Out:
#               count unique         top freq          mean           std  \
# Product          76      3       TM195   40           NaN           NaN
# Age            76.0    NaN         NaN  NaN     28.565789      6.342104
# Gender           76      1      Female   76           NaN           NaN
# Education      76.0    NaN         NaN  NaN     15.394737       1.44295
# MaritalStatus    76      2   Partnered   46           NaN           NaN
# Usage          76.0    NaN         NaN  NaN      3.184211      1.016012
# Fitness        76.0    NaN         NaN  NaN      3.026316      0.832245
# Income         76.0    NaN         NaN  NaN  49828.907895  12557.690428
# Miles          76.0    NaN         NaN  NaN     90.013158     44.782882
# Age_Bin          76      3   Age_30_50   28           NaN           NaN
# Income_Bin       76      3  Income_Mid   36           NaN           NaN
#
#                    min       25%      50%      75%      max
# ...

# %%
#Countplot for product for female date with product as hue
plt.figure(figsize=(15,7))
sns.countplot(data=df_Female, x= "Age_Bin", hue = "Product")
# Out:
# <AxesSubplot:xlabel='Age_Bin', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Females in the 30-50 age bin favor the TM498

# %%
#Extract a data frame consisting only of male cusomers for furher analysis of this category
df_Male = df[df["Gender"] == "Male"]

# %%
#View top five rows of male dataframe data
df_Male.head()
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles  \
# 0   TM195   18   Male         14        Single      3        4   29562    112
# 1   TM195   19   Male         15        Single      2        3   31836     75
# 3   TM195   19   Male         12        Single      3        3   32973     85
# 4   TM195   20   Male         13     Partnered      4        2   35247     47
# 7   TM195   21   Male         13        Single      3        3   32973     85
#
#      Age_Bin  Income_Bin
# 0  Age_18_24  Income_Low
# 1  Age_18_24  Income_Low
# 3  Age_18_24  Income_Low
# 4  Age_18_24  Income_Low
# 7  Age_18_24  Income_Low

# %%
#Descriptive statistics for male dataframe data
df_Male.describe(include="all").T
# Out:
#                count unique         top freq          mean           std  \
# Product          104      3       TM195   40           NaN           NaN
# Age            104.0    NaN         NaN  NaN     28.951923      7.377978
# Gender           104      1        Male  104           NaN           NaN
# Education      104.0    NaN         NaN  NaN     15.701923      1.728571
# MaritalStatus    104      2   Partnered   61           NaN           NaN
# Usage          104.0    NaN         NaN  NaN      3.653846      1.095172
# Fitness        104.0    NaN         NaN  NaN      3.519231      0.994946
# Income         104.0    NaN         NaN  NaN  56562.759615  18421.687779
# Miles          104.0    NaN         NaN  NaN    112.826923     54.702451
# Age_Bin          104      3   Age_30_50   39           NaN           NaN
# Income_Bin       104      3  Income_Mid   42           NaN           NaN
#
#                    min      25%      50%       75%       max
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df_Male, x= "Age_Bin", hue = "Product")
# Out:
# <AxesSubplot:xlabel='Age_Bin', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The 25-29 age bin has the highest proportion of TM798 users

# %%
#extract a dataframe for TM195 users
df_TM195 = df[df["Product"] == "TM195"]

# %%
#View top 5 rows of dataframe
df_TM195.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   TM195   18    Male         14        Single      3        4   29562
# 1   TM195   19    Male         15        Single      2        3   31836
# 2   TM195   19  Female         14     Partnered      4        3   30699
# 3   TM195   19    Male         12        Single      3        3   32973
# 4   TM195   20    Male         13     Partnered      4        2   35247
#
#    Miles    Age_Bin  Income_Bin
# 0    112  Age_18_24  Income_Low
# 1     75  Age_18_24  Income_Low
# 2     66  Age_18_24  Income_Low
# 3     85  Age_18_24  Income_Low
# 4     47  Age_18_24  Income_Low

# %%
#View bottom five rows of dataframe
df_TM195.tail()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 75   TM195   43    Male         16     Partnered      3        3   53439
# 76   TM195   44  Female         16        Single      3        4   57987
# 77   TM195   46  Female         16     Partnered      3        2   60261
# 78   TM195   47    Male         16     Partnered      4        3   56850
# 79   TM195   50  Female         16     Partnered      3        3   64809
#
#     Miles    Age_Bin  Income_Bin
# 75     66  Age_30_50  Income_Mid
# 76     75  Age_30_50   Income_Hi
# 77     47  Age_30_50   Income_Hi
# 78     94  Age_30_50   Income_Hi
# 79     66  Age_30_50   Income_Hi

# %%
#Descriptive statistics for TM195 user dataframe
df_TM195.describe(include="all").T
# Out:
#               count unique         top freq       mean         std      min  \
# Product          80      1       TM195   80        NaN         NaN      NaN
# Age            80.0    NaN         NaN  NaN      28.55    7.221452     18.0
# Gender           80      2        Male   40        NaN         NaN      NaN
# Education      80.0    NaN         NaN  NaN    15.0375    1.216383     12.0
# MaritalStatus    80      2   Partnered   48        NaN         NaN      NaN
# Usage          80.0    NaN         NaN  NaN     3.0875    0.782624      2.0
# Fitness        80.0    NaN         NaN  NaN     2.9625     0.66454      1.0
# Income         80.0    NaN         NaN  NaN  46418.025  9075.78319  29562.0
# Miles          80.0    NaN         NaN  NaN    82.7875   28.874102     38.0
# Age_Bin          80      3   Age_18_24   27        NaN         NaN      NaN
# Income_Bin       80      3  Income_Mid   36        NaN         NaN      NaN
#
#                    25%      50%      75%      max
# ...

# %% [markdown]
# ### Observations
#
# - All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM195 Customer
#   Profile"

# %%
#Histogram and boxplot of age for TM195 users
histogram_boxplot(df_TM195,'Age')

# %% [markdown]
# ### Observations
#
# - Age data is right skewed.

# %%
#Determine modal value for TM195 user age
df_TM195["Age"].mode()
# Out:
# 0    23
# Name: Age, dtype: int64

# %%
#Histogram and boxpot for TM195 user education data
histogram_boxplot(df_TM195,'Education')

# %%
df_TM195["Education"].mode()
# Out:
# 0    16
# Name: Education, dtype: int64

# %%
#Boxplot and histogram for TM195 user usage data
histogram_boxplot(df_TM195,'Usage')

# %%
#Calculate TM195 user modal value of usage
df_TM195["Usage"].mode()
# Out:
# 0    3
# Name: Usage, dtype: int64

# %%
#Boxplot and histogram for TM195 user fitness data
histogram_boxplot(df_TM195,'Fitness')

# %%
#Calculate modal value for TM195 user fitness
df_TM195["Fitness"].mode()
# Out:
# 0    3
# Name: Fitness, dtype: int64

# %%
#Boxplot and histogram for TM195 user income
histogram_boxplot(df_TM195,'Income')

# %%
#Boxplot and histogram for TM195 user miles data
histogram_boxplot(df_TM195,'Miles')

# %% [markdown]
# ### Observations
#
# - There are three outliers to the high side but this data was not discarded.

# %%
#Calculate modal value for TM195 user miles
df_TM195["Miles"].mode()
# Out:
# 0    85
# Name: Miles, dtype: int64

# %%
# Filter dataframe to determine maximum income for TM195 users with miles data >= 80
# Determine maximum income of this group

df_TM195_Miles = df[(df['Miles'] >= 80) & (df['Product'] == 'TM195')]
df_TM195_Miles['Income'].max()
# Out:
# 68220

# %%
# Overview of categorical data columns for TM195 users
# Determine the counts of unique categorical levels in each column
# Make list of columns containing categorical data
cols_cat = ['Gender', 'MaritalStatus', 'Age_Bin', 'Income_Bin']

# Print unique categorical level counts for each column
for column in cols_cat:
  print(df_TM195[column].value_counts())
  print('-' * 20)
# Out:
# Male      40
# Female    40
# Name: Gender, dtype: int64
# --------------------
# Partnered    48
# Single       32
# Name: MaritalStatus, dtype: int64
# --------------------
# Age_18_24    27
# Age_30_50    27
# Age_25_29    26
# Name: Age_Bin, dtype: int64
# --------------------
# Income_Mid    36
# Income_Low    34
# Income_Hi     10
# Name: Income_Bin, dtype: int64
# --------------------

# %%
#Calculate normalized fraction of unique categorical levels in each column
for column in cols_cat:
  print(df_TM195[column].value_counts(normalize=True))
  print('-' * 20)
# Out:
# Male      0.5
# Female    0.5
# Name: Gender, dtype: float64
# --------------------
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
# --------------------
# Age_18_24    0.3375
# Age_30_50    0.3375
# Age_25_29    0.3250
# Name: Age_Bin, dtype: float64
# --------------------
# Income_Mid    0.450
# Income_Low    0.425
# Income_Hi     0.125
# Name: Income_Bin, dtype: float64
# --------------------

# %% [markdown]
# ### Observations
#
# - All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM195 Customer
#   Profile"

# %%
#Countplot for gender for TM195 users
sns.countplot(data=df_TM195, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Countplot for marital status for TM195 users
sns.countplot(data=df_TM195, x="MaritalStatus")
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
#Countplot for age bins for TM195 users
sns.countplot(data=df_TM195, x="Age_Bin")
# Out:
# <AxesSubplot:xlabel='Age_Bin', ylabel='count'>

# %%
#Countplot for income bins for TM195 users
sns.countplot(data=df_TM195, x="Income_Bin")
# Out:
# <AxesSubplot:xlabel='Income_Bin', ylabel='count'>

# %%
#Extract dataframe to explore TM498 users
df_TM498 = df[df["Product"] == "TM498"]

# %%
#View top five rows for TM498 user dataframe
df_TM498.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   TM498   19    Male         14        Single      3        3   31836
# 81   TM498   20    Male         14        Single      2        3   32973
# 82   TM498   20  Female         14     Partnered      3        3   34110
# 83   TM498   20    Male         14        Single      3        3   38658
# 84   TM498   21  Female         14     Partnered      5        4   34110
#
#     Miles    Age_Bin  Income_Bin
# 80     64  Age_18_24  Income_Low
# 81     53  Age_18_24  Income_Low
# 82    106  Age_18_24  Income_Low
# 83     95  Age_18_24  Income_Low
# 84    212  Age_18_24  Income_Low

# %%
#View bottom five rows for TM498 user dataframe
df_TM498.tail()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 135   TM498   40  Female         16     Partnered      3        3   61398
# 136   TM498   40  Female         16        Single      3        3   57987
# 137   TM498   40    Male         16     Partnered      3        3   64809
# 138   TM498   45    Male         16     Partnered      2        2   54576
# 139   TM498   48    Male         16     Partnered      2        3   57987
#
#      Miles    Age_Bin  Income_Bin
# 135     85  Age_30_50   Income_Hi
# 136     85  Age_30_50   Income_Hi
# 137     95  Age_30_50   Income_Hi
# 138     42  Age_30_50  Income_Mid
# 139     64  Age_30_50   Income_Hi

# %%
#High level statistical summary of TM498 dataframe
df_TM498.describe(include="all").T
# Out:
#               count unique         top freq       mean          std      min  \
# Product          60      1       TM498   60        NaN          NaN      NaN
# Age            60.0    NaN         NaN  NaN       28.9     6.645248     19.0
# Gender           60      2        Male   31        NaN          NaN      NaN
# Education      60.0    NaN         NaN  NaN  15.116667     1.222552     12.0
# MaritalStatus    60      2   Partnered   36        NaN          NaN      NaN
# Usage          60.0    NaN         NaN  NaN   3.066667     0.799717      2.0
# Fitness        60.0    NaN         NaN  NaN        2.9      0.62977      1.0
# Income         60.0    NaN         NaN  NaN   48973.65  8653.989388  31836.0
# Miles          60.0    NaN         NaN  NaN  87.933333    33.263135     21.0
# Age_Bin          60      3   Age_30_50   27        NaN          NaN      NaN
# Income_Bin       60      3  Income_Mid   33        NaN          NaN      NaN
#
# ...

# %% [markdown]
# ### Observations
#
# - All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM498 Customer
#   Profile"

# %%
#Boxplot and histogram of TM498 user age data
histogram_boxplot(df_TM498,'Age')

# %% [markdown]
# ### Observations
#
# - Age data is right skewed

# %%
#calculate TM498 user age modal value
df_TM498["Age"].mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %%
#Boxplot and histogram for TM498 user education data
histogram_boxplot(df_TM498,'Education')

# %%
#Calculate TM498 user education modal value
df_TM498["Education"].mode()
# Out:
# 0    16
# Name: Education, dtype: int64

# %%
#Boxplot and histogram for TM498 user usage data
histogram_boxplot(df_TM498,'Usage')

# %%
#Calculate TM498 user modal value for usage
df_TM498["Usage"].mode()
# Out:
# 0    3
# Name: Usage, dtype: int64

# %%
#Boxplot and histogram for TM498 user fitness data
histogram_boxplot(df_TM498,'Fitness')

# %%
#Calculate modal value for TM498 user fitness data
df_TM498["Fitness"].mode()
# Out:
# 0    3
# Name: Fitness, dtype: int64

# %%
#Boxplot and histogram for TM498 income data
histogram_boxplot(df_TM498,'Income')

# %% [markdown]
# ### Observations
#
# - Data appears to be relatively close to a normal distribution.

# %%
#Calculate modal value of TM498 user income
df_TM498["Income"].mode()
# Out:
# 0    45480
# Name: Income, dtype: int64

# %%
#Boxplot and histogram for TM498 user miles
histogram_boxplot(df_TM498,'Miles')

# %% [markdown]
# ### Observations
#
# - There are very few values above 130 miles and those two values are outliers.

# %%
#Calculate modal value of TM498 modal values for miles data
df_TM498["Miles"].mode()
# Out:
# 0    95
# Name: Miles, dtype: int64

# %%
# Filter dataframe to determine maximum income for TM498 users with miles data >= 80
# Determine maximum income of this group

df_TM498_Miles = df[(df['Miles'] >= 80) & (df['Product'] == 'TM498')]
df_TM498_Miles['Income'].max()
# Out:
# 67083

# %%
# Overview of TM498 user categorical data columns
# Determine the counts of unique categorical levels in each column
# Make list of columns containing categorical data
cols_cat = ['Gender', 'MaritalStatus', 'Age_Bin', 'Income_Bin']

# Print unique categorical level counts for each column
for column in cols_cat:
  print(df_TM498[column].value_counts())
  print('-' * 20)
# Out:
# Male      31
# Female    29
# Name: Gender, dtype: int64
# --------------------
# Partnered    36
# Single       24
# Name: MaritalStatus, dtype: int64
# --------------------
# Age_30_50    27
# Age_18_24    17
# Age_25_29    16
# Name: Age_Bin, dtype: int64
# --------------------
# Income_Mid    33
# Income_Low    15
# Income_Hi     12
# Name: Income_Bin, dtype: int64
# --------------------

# %%
#Calculate normalized fraction of unique categorical levels in each column
for column in cols_cat:
  print(df_TM498[column].value_counts(normalize=True))
  print('-' * 20)
# Out:
# Male      0.516667
# Female    0.483333
# Name: Gender, dtype: float64
# --------------------
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
# --------------------
# Age_30_50    0.450000
# Age_18_24    0.283333
# Age_25_29    0.266667
# Name: Age_Bin, dtype: float64
# --------------------
# Income_Mid    0.55
# Income_Low    0.25
# Income_Hi     0.20
# Name: Income_Bin, dtype: float64
# --------------------

# %% [markdown]
# ### All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM498 Customer Profile"

# %%
#Countplot of gender for TM498 users
sns.countplot(data=df_TM498, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Countplot for TM498 user marital status
sns.countplot(data=df_TM498, x="MaritalStatus")
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
#Countplot for TM498 user age bins
sns.countplot(data=df_TM498, x="Age_Bin")
# Out:
# <AxesSubplot:xlabel='Age_Bin', ylabel='count'>

# %% [markdown]
# The age 30-50 bin is most dominant for TM498 users

# %%
#Countplot for TM498 user income bins
sns.countplot(data=df_TM498, x="Income_Bin")
# Out:
# <AxesSubplot:xlabel='Income_Bin', ylabel='count'>

# %% [markdown]
# The middle income bin is most dominant for TM498 users

# %%
#Extract dataframe to explore TM798 user data
df_TM798 = df[df["Product"] == "TM798"]

# %%
#View first five rows of dataframe
df_TM798.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   TM798   22    Male         14        Single      4        3   48658
# 141   TM798   22    Male         16        Single      3        5   54781
# 142   TM798   22    Male         18        Single      4        5   48556
# 143   TM798   23    Male         16        Single      4        5   58516
# 144   TM798   23  Female         18        Single      5        4   53536
#
#      Miles    Age_Bin  Income_Bin
# 140    106  Age_18_24  Income_Mid
# 141    120  Age_18_24  Income_Mid
# 142    200  Age_18_24  Income_Mid
# 143    140  Age_18_24   Income_Hi
# 144    100  Age_18_24  Income_Mid

# %%
#View last 5 rows of dataframe
df_TM798.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles    Age_Bin Income_Bin
# 175    200  Age_30_50  Income_Hi
# 176    200  Age_30_50  Income_Hi
# 177    160  Age_30_50  Income_Hi
# 178    120  Age_30_50  Income_Hi
# 179    180  Age_30_50  Income_Hi

# %%
#Present descriptive statistics for TM798 users
df_TM798.describe(include="all").T
# Out:
#               count unique        top freq       mean          std      min  \
# Product          40      1      TM798   40        NaN          NaN      NaN
# Age            40.0    NaN        NaN  NaN       29.1     6.971738     22.0
# Gender           40      2       Male   33        NaN          NaN      NaN
# Education      40.0    NaN        NaN  NaN     17.325     1.639066     14.0
# MaritalStatus    40      2  Partnered   23        NaN          NaN      NaN
# Usage          40.0    NaN        NaN  NaN      4.775     0.946993      3.0
# Fitness        40.0    NaN        NaN  NaN      4.625     0.667467      3.0
# Income         40.0    NaN        NaN  NaN  75441.575  18505.83672  48556.0
# Miles          40.0    NaN        NaN  NaN      166.9    60.066544     80.0
# Age_Bin          40      3  Age_25_29   17        NaN          NaN      NaN
# Income_Bin       40      2  Income_Hi   31        NaN          NaN      NaN
#
#                     25%      50%      75%       max
# ...

# %% [markdown]
# All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM798 Customer Profile"

# %%
#Boxplot and histogram of TM798 user age data
histogram_boxplot(df_TM798,'Age')

# %% [markdown]
# ### Observations
#
# - The data is right skewed and has high outliers.

# %%
#Calculate modal age for TM798 users
df_TM798["Age"].mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %%
#Boxplot and histogram for TM798 user education data
histogram_boxplot(df_TM798,'Education')

# %%
#Calculate modal value for TM798 user education data
df_TM798["Education"].mode()
# Out:
# 0    18
# Name: Education, dtype: int64

# %%
#Boxplot and histogram for TM798 user usage data
histogram_boxplot(df_TM798,'Usage')

# %%
#Calculate modal value for TM498 usage data
df_TM798["Usage"].mode()
# Out:
# 0    4
# Name: Usage, dtype: int64

# %%
#Boxplot and histogram for TM798 user fitness data
histogram_boxplot(df_TM798,'Fitness')

# %% [markdown]
# ### Observations
#
# - The fitness data is left skewed.

# %%
#Calculate modal value of TM798 user fitness data
df_TM798["Fitness"].mode()
# Out:
# 0    5
# Name: Fitness, dtype: int64

# %%
#Boxplot and histogram for TM798 user income data
histogram_boxplot(df_TM798,'Income')

# %% [markdown]
# ### Observations
#
# - Income data is somewhat bimodal

# %%
#Boxplot and histogram for TM798 user miles data
histogram_boxplot(df_TM798,'Miles')

# %% [markdown]
# ### Observations
#
# - Miles data is right skewed

# %%
#Print value counts for TM798 user miles data
print(df_TM798["Miles"].value_counts().sort_index(ascending = True))
# Out:
# 80     1
# 100    7
# 106    1
# 120    3
# 140    1
# 150    4
# 160    5
# 170    1
# 180    6
# 200    6
# 240    1
# 260    1
# 280    1
# 300    1
# 360    1
# Name: Miles, dtype: int64

# %%
# Filter dataframe to determine minimum income for TM798 users with miles data >= 80
# Determine mininmum income of this group

df_TM798_Miles = df[(df['Miles'] >= 80) & (df['Product'] == 'TM798')]
df_TM798_Miles['Income'].min()
# Out:
# 48556

# %%
# Overview of TM798 user categorical data columns
# Determine the counts of unique categorical levels in each column
# Make list of columns containing categorical data
cols_cat = ['Gender', 'MaritalStatus', 'Age_Bin', 'Income_Bin']

# Print unique categorical level counts for each column
for column in cols_cat:
  print(df_TM798[column].value_counts())
  print('-' * 20)
# Out:
# Male      33
# Female     7
# Name: Gender, dtype: int64
# --------------------
# Partnered    23
# Single       17
# Name: MaritalStatus, dtype: int64
# --------------------
# Age_25_29    17
# Age_30_50    13
# Age_18_24    10
# Name: Age_Bin, dtype: int64
# --------------------
# Income_Hi     31
# Income_Mid     9
# Income_Low     0
# Name: Income_Bin, dtype: int64
# --------------------

# %%
#Calculate normalized fraction of unique categorical levels in each column
for column in cols_cat:
  print(df_TM798[column].value_counts(normalize=True))
  print('-' * 20)
# Out:
# Male      0.825
# Female    0.175
# Name: Gender, dtype: float64
# --------------------
# Partnered    0.575
# Single       0.425
# Name: MaritalStatus, dtype: float64
# --------------------
# Age_25_29    0.425
# Age_30_50    0.325
# Age_18_24    0.250
# Name: Age_Bin, dtype: float64
# --------------------
# Income_Hi     0.775
# Income_Mid    0.225
# Income_Low    0.000
# Name: Income_Bin, dtype: float64
# --------------------

# %% [markdown]
# ### Observations
#
# - All of the statistics above are discussed in the section at the top of the report entitled "Summary of TM798 Customer
#   Profile"

# %%
#Countplot for TM798 user gender
sns.countplot(data=df_TM798, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - Male TM798 users greatly outnumber female users

# %%
#Countplot for TM798 user marital status
sns.countplot(data=df_TM798, x="MaritalStatus")
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The proportion of partnered users is close to that of the overall dataset

# %%
#Countplot of TM798 user age bin data
sns.countplot(data=df_TM798, x="Age_Bin")
# Out:
# <AxesSubplot:xlabel='Age_Bin', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The 25-29 age bin has the greatest frequency among TM798 users

# %%
#Countplot for TM798 user income bins
sns.countplot(data=df_TM798, x="Income_Bin")
# Out:
# <AxesSubplot:xlabel='Income_Bin', ylabel='count'>

# %% [markdown]
# ### Observations
#
# - The high income bin is the most dominant income bin for TM798 users.
